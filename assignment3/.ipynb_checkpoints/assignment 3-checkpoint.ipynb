# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv', nrows=200)

# %%
df.columns
# Out:
# Index(['# Timestamp', 'Type of mobile', 'MMSI', 'Latitude', 'Longitude',
#        'Navigational status', 'ROT', 'SOG', 'COG', 'Heading', 'IMO',
#        'Callsign', 'Name', 'Ship type', 'Cargo type', 'Width', 'Length',
#        'Type of position fixing device', 'Draught', 'Destination', 'ETA',
#        'Data source type', 'A', 'B', 'C', 'D'],
#       dtype='object')

# %%
df = df.rename(columns=lambda x: x.lower().replace(' ', '_'))
df
# Out:
#              #_timestamp type_of_mobile       mmsi  latitude  longitude  \
# 0    01/05/2023 00:00:00   Base Station    2190064   56.7166   11.51910
# 1    01/05/2023 00:00:00        Class A  250006549   57.6578   11.01110
# 2    01/05/2023 00:00:00        Class A  219340000   56.6968    8.21854
# 3    01/05/2023 00:00:00        Class A  265012560   55.4109   12.93320
# 4    01/05/2023 00:00:00        Class A  219019887   55.8648   10.54880
# ..                   ...            ...        ...       ...        ...
# 195  01/05/2023 00:00:01        Class A  230175220   57.5924    9.95816
# 196  01/05/2023 00:00:01        Class A  219016555   54.8760   11.02860
# 197  01/05/2023 00:00:01        Class A  636015279   55.1730   13.79730
# 198  01/05/2023 00:00:01        Class A  265009000   57.6807   11.30200
# 199  01/05/2023 00:00:01        Class A  219005826   56.8036    9.01996
#
#             navigational_status  rot   sog    cog  heading  ... length  \
# 0                 Unknown value  NaN   NaN    NaN      NaN  ...    NaN
# 1        Under way using engine  0.0  12.0  135.5    132.0  ...    NaN
# 2        Under way using engine  NaN   0.0  300.4      NaN  ...    NaN
# 3        Under way using engine  0.0   0.0  265.4    337.0  ...    NaN
# 4        Under way using engine  0.0   0.0    8.0      8.0  ...    NaN
# ..                          ...  ...   ...    ...      ...  ...    ...
# 195      Under way using engine  NaN   0.0  345.0      NaN  ...    NaN
# 196      Under way using engine  0.0   0.0  249.0    249.0  ...    NaN
# 197      Under way using engine  0.0   7.1   97.4     98.0  ...    NaN
# 198  Restricted maneuverability  0.0   7.3  318.8    320.0  ...    NaN
# 199      Under way using engine  NaN   0.0    NaN      NaN  ...    NaN
#
#     type_of_position_fixing_device draught destination  eta  data_source_type  \
# 0                              GPS     NaN         NaN  NaN               AIS
# 1                        Undefined     NaN         NaN  NaN               AIS
# 2                        Undefined     NaN         NaN  NaN               AIS
# 3                        Undefined     NaN         NaN  NaN               AIS
# 4                        Undefined     NaN         NaN  NaN               AIS
# ..                             ...     ...         ...  ...               ...
# 195                      Undefined     NaN         NaN  NaN               AIS
# 196                      Undefined     NaN         NaN  NaN               AIS
# 197                      Undefined     NaN         NaN  NaN               AIS
# 198                      Undefined     NaN         NaN  NaN               AIS
# 199                      Undefined     NaN         NaN  NaN               AIS
#
#       a   b   c   d
# 0   NaN NaN NaN NaN
# 1   NaN NaN NaN NaN
# 2   NaN NaN NaN NaN
# 3   NaN NaN NaN NaN
# 4   NaN NaN NaN NaN
# ..   ..  ..  ..  ..
# 195 NaN NaN NaN NaN
# 196 NaN NaN NaN NaN
# 197 NaN NaN NaN NaN
# 198 NaN NaN NaN NaN
# 199 NaN NaN NaN NaN
#
# [200 rows x 26 columns]

# %% [markdown]
# ## Connecting to the database

# %%
from pymongo import MongoClient

# %%
mongos1 = "mongodb://localhost:27019/"
mongos2 = "mongodb://localhost:27020/"

# %%
client = MongoClient(mongos1)
db = client["ships"]
collection = db["ship_positions"]

# %%
def map_data(indices):
    data = df.iloc[indices]
    insert = data.to_dict()
    result = collection.insert_many(data)
    print("inserted ids:", result)
